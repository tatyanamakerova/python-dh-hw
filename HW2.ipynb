# %%
# Дан текст, записанный в переменную

text = """Это может показаться странным, Гарри, но, может быть, для власти лучше всего приспособлены те,
кто никогда к ней не стремился. Такие, как ты, принимающие руководство, потому что им его поручили, 
надевающие генеральский мундир по необходимости, а потом с удивлением обнаруживающие, что он сидит на них неплохо."""

# Чтобы его разбить на слова, используем функцию split() и записываем ее в переменную 

quotation = text.split()

# Будущие биграммы записываем в переменную bigrams, а затем используем цикл for для создания списка биграмм. 
# Функция len() нужна для того, чтобы узнать длину переменной quotation, а согласно Подсказке №2 количество биграмм в тексте = количество биграмм в тексте - 1.

bigrams = []
for i in range(len(quotation)-1):
    bigrams.append([quotation[i],quotation[i+1]])
print(bigrams)
# Out:
# [['Это', 'может'], ['может', 'показаться'], ['показаться', 'странным,'], ['странным,', 'Гарри,'], ['Гарри,', 'но,'], ['но,', 'может'], ['может', 'быть,'], ['быть,', 'для'], ['для', 'власти'], ['власти', 'лучше'], ['лучше', 'всего'], ['всего', 'приспособлены'], ['приспособлены', 'те,'], ['те,', 'кто'], ['кто', 'никогда'], ['никогда', 'к'], ['к', 'ней'], ['ней', 'не'], ['не', 'стремился.'], ['стремился.', 'Такие,'], ['Такие,', 'как'], ['как', 'ты,'], ['ты,', 'принимающие'], ['принимающие', 'руководство,'], ['руководство,', 'потому'], ['потому', 'что'], ['что', 'им'], ['им', 'его'], ['его', 'поручили,'], ['поручили,', 'надевающие'], ['надевающие', 'генеральский'], ['генеральский', 'мундир'], ['мундир', 'по'], ['по', 'необходимости,'], ['необходимости,', 'а'], ['а', 'потом'], ['потом', 'с'], ['с', 'удивлением'], ['удивлением', 'обнаруживающие,'], ['обнаруживающие,', 'что'], ['что', 'он'], ['он', 'сидит'], ['сидит', 'на'], ['на', 'них'], ['них', 'неплохо.']]

# %%
#импортируем модуль
import os
os.chdir ('/Users/tatyanamakerova/Desktop/prog/poems')

#распечатываем текущую директорию
print(os.getcwd()) 
    
#распечатываем количество файлов в текущей директории 
for root, dirs, files in os.walk('/Users/tatyanamakerova/Desktop/prog/poems'): 
    print (dirs) 
    print (files) 
    print(len(files))
# Out:
# /Users/tatyanamakerova/Desktop/prog/poems
# ['сказки', 'котики']
# ['poems.txt', 'шредингер.txt', '.DS_Store', 'боль.txt', 'ворон.txt', 'кладь.txt', 'деды.txt', 'ночь.txt']
# 8
# []
# ['король.txt', 'крестная.txt', 'гримм.txt', 'королевич.txt', 'яга.txt']
# 5
# []
# ['кот.txt', 'пушок.txt', 'лео.txt']
# 3

# %%
#записываем текст в переменную
poem = """Удивительная кошка

Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""

#узнаем длину текста
print (len(poem))

#очищаем текст от пунктуации 
words = [word.strip("!?.,-") for word in poem.split()]
print(words)

#объединяем слова с помощью функции join()
stroka = ' '.join(words)
print(stroka)

#приводим все слова по нижнему регистру
print ([word.lower() if word.istitle() else word for word in words])

#узнаем длину получившегося текста и распечатываем
print (len(words))

#узнаем количество уникальных слов
print (len([word for word in words if words.count(word) == 1]))

#распечатываем последние 10 слов
print (words[-10:])

#распечатываем переменную stroka из п.3 через знак переноса строки
new_words = '\n'.join(words)
print(new_words)

#распечатываем с 20 по 30 символы
print(new_words[19:30])

#разбиваем текст на биграммы и записываем их переменную
bigrams = []
for i in range (len(words)-1):
    bigrams.append((words[i], words[i+1]))
print(bigrams)

#считаем частотность биграмм
for bigram in bigrams:
    frequency = bigrams.count(bigram)
    print(frequency)
# Out:
# 290
# ['Удивительная', 'кошка', 'Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# Удивительная кошка Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит
# ...
